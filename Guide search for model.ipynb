PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_04_06 PM.png
# blue2/Screenshot - 2_22_2020 , 11_04_07 PM.png
# blue2/Screenshot - 2_22_2020 , 11_04_08 PM.png
# blue2/Screenshot - 2_22_2020 , 11_05_52 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_05_52 PM.png
# blue2/Screenshot - 2_22_2020 , 11_05_53 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_05_53 PM.png
# blue2/Screenshot - 2_22_2020 , 11_05_54 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_05_54 PM.png
# blue2/Screenshot - 2_22_2020 , 11_05_55 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_05_55 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_05_55 PM 004.png
# blue2/Screenshot - 2_22_2020 , 11_05_55 PM.png
# blue2/Screenshot - 2_22_2020 , 11_05_56 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_06 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_09 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_10 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_11 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_13 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_15 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_16 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_18 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_19 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_21 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_06_21 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_06_21 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_22 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_06_22 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_06_22 PM 004.png
# blue2/Screenshot - 2_22_2020 , 11_06_22 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_23 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_06_23 PM 004.png
# blue2/Screenshot - 2_22_2020 , 11_06_24 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_06_24 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_06_24 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_25 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_26 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_27 PM.png
# blue2/Screenshot - 2_22_2020 , 11_06_29 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_06_29 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_06_29 PM.png
# blue2/Screenshot - 2_22_2020 , 11_07_56 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_07_56 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_07_56 PM.png
# blue2/Screenshot - 2_22_2020 , 11_07_57 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_07_57 PM.png
# blue2/Screenshot - 2_22_2020 , 11_07_58 PM.png
# blue2/Screenshot - 2_22_2020 , 11_07_59 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_07_59 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_07_59 PM 004.png
# blue2/Screenshot - 2_22_2020 , 11_07_59 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_00 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_08_00 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_08_00 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_01 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_08_01 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_02 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_03 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_05 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_06 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_08 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_08_09 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_08_09 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_10 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_11 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_13 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_14 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_15 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_16 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_19 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_08_20 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_22 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_24 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_25 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_08_25 PM.png
# blue2/Screenshot - 2_22_2020 , 11_08_26 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_08_26 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_32 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_33 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_09_33 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_09_33 PM 004.png
# blue2/Screenshot - 2_22_2020 , 11_09_33 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_34 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_09_34 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_09_34 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_35 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_09_35 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_09_35 PM 004.png
# blue2/Screenshot - 2_22_2020 , 11_09_35 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_36 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_09_36 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_09_36 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_37 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_09_37 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_09_37 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_38 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_43 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_09_43 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_09_43 PM 004.png
# blue2/Screenshot - 2_22_2020 , 11_09_43 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_44 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_09_44 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_09_44 PM 004.png
# blue2/Screenshot - 2_22_2020 , 11_09_44 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_45 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_46 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_09_46 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_48 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_50 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_52 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_09_52 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_54 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_56 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_57 PM.png
# blue2/Screenshot - 2_22_2020 , 11_09_58 PM.png
# blue2/Screenshot - 2_22_2020 , 11_10_00 PM.png
# blue2/Screenshot - 2_22_2020 , 11_10_01 PM.png
# blue2/Screenshot - 2_22_2020 , 11_10_03 PM.png
# blue2/Screenshot - 2_22_2020 , 11_10_04 PM.png
# blue2/Screenshot - 2_22_2020 , 11_10_05 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_10_05 PM 003.png
# blue2/Screenshot - 2_22_2020 , 11_10_05 PM 004.png
# blue2/Screenshot - 2_22_2020 , 11_10_05 PM.png
# blue2/Screenshot - 2_22_2020 , 11_10_06 PM 002.png
# blue2/Screenshot - 2_22_2020 , 11_10_06 PM.png

# %%
# !mkdir mynewfiles/spike
# !mkdir mynewfiles/blue

# %%
# !mv tempzipfolder/spike2/*.*    mynewfiles/spike

# %%
# !mv tempzipfolder/blue2/*.*    mynewfiles/blue

# %%
# !ls mynewfiles
# Out:
# blue  spike

# %%
# !mkdir mynewfilesTEM

# %%
# !mkdir mynewfilesTEM/blue

# %%
from google.colab import files
#uploaded = files.upload()

# %%
# !wget https://raw.githubusercontent.com/rajagopalmotivate1/COVID_NanoAID/master/10.jpg
# Out:
# --2020-10-02 04:31:08--  https://raw.githubusercontent.com/rajagopalmotivate1/COVID_NanoAID/master/10.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 452809 (442K) [image/jpeg]
# Saving to: ‘10.jpg’
#
# 10.jpg              100%[===================>] 442.20K  --.-KB/s    in 0.04s
#
# 2020-10-02 04:31:08 (11.0 MB/s) - ‘10.jpg’ saved [452809/452809]

# %%
# !mv 10.jpg mynewfilesTEM/blue/100.jpg

# %%
import os



rock_dir = os.path.join('mynewfiles/spike')
paper_dir = os.path.join('mynewfiles/blue')

print('total training  images:', len(os.listdir(rock_dir)))
print('total training  images:', len(os.listdir(paper_dir)))

rock_files = os.listdir(rock_dir)
print(rock_files[:10])

paper_files = os.listdir(paper_dir)
print(paper_files[:10])
# Out:
# total training  images: 647
# total training  images: 623
# ['Screenshot - 2_22_2020 , 9_19_26 PM.png', 'Screenshot - 2_22_2020 , 10_24_32 PM.png', 'Screenshot - 2_22_2020 , 9_14_12 PM.png', 'Screenshot - 2_22_2020 , 10_35_22 PM.png', 'Screenshot - 2_22_2020 , 10_30_09 PM.png', 'Screenshot - 2_22_2020 , 10_25_33 PM.png', 'Screenshot - 2_22_2020 , 10_32_01 PM.png', 'Screenshot - 2_22_2020 , 10_32_03 PM 002.png', 'Screenshot - 2_22_2020 , 10_21_48 PM 002.png', 'Screenshot - 2_22_2020 , 10_30_03 PM.png']
# ['Screenshot - 2_22_2020 , 11_03_44 PM 002.png', 'Screenshot - 2_22_2020 , 10_44_28 PM.png', 'Screenshot - 2_22_2020 , 11_02_00 PM.png', 'Screenshot - 2_22_2020 , 11_06_27 PM.png', 'Screenshot - 2_22_2020 , 10_54_58 PM 003.png', 'Screenshot - 2_22_2020 , 10_48_41 PM 002.png', 'Screenshot - 2_22_2020 , 10_48_28 PM.png', 'Screenshot - 2_22_2020 , 11_06_23 PM 003.png', 'Screenshot - 2_22_2020 , 10_49_38 PM.png', 'Screenshot - 2_22_2020 , 11_00_52 PM 003.png']

# %%
SIZE = 224

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Input, Dropout
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D
import matplotlib.pyplot as plt
from keras import backend as K
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

from keras.preprocessing import image
# Out:
# Using TensorFlow backend.

# %%
DATASETCLASSMODE= 'input'
#DATASETCLASSMODE= 'categorical'

# %%
BATCHSIZE=64

# %%
TRAINING_DIR = "mynewfiles/"

datagen = ImageDataGenerator(validation_split=0.1, rescale=1./255,      rotation_range=4,
     horizontal_flip=True,                                                                
     fill_mode='wrap')

train_generator = datagen.flow_from_directory(
    TRAINING_DIR, 
    subset='training',
    target_size=(SIZE,SIZE),
         shuffle=True,     batch_size=BATCHSIZE,
	  class_mode='input'
)

validation_generator = datagen.flow_from_directory(
    TRAINING_DIR,
    subset='validation',
    	target_size=(SIZE,SIZE),
         shuffle=True,     batch_size=BATCHSIZE,
	class_mode='input'
)




test_datagen = ImageDataGenerator( rescale=1./255)


test_generator = test_datagen.flow_from_directory(
    TRAINING_DIR,
    target_size=(SIZE,SIZE),
    batch_size=BATCHSIZE,
    class_mode='input',
    shuffle=True,
    seed=42
)
# Out:
# Found 1144 images belonging to 2 classes.
# Found 126 images belonging to 2 classes.
# Found 1270 images belonging to 2 classes.

# %%
for image_batch, label_batch in test_generator:
  print("Image batch shape: ", image_batch.shape)
  print("Label batch shape: ", label_batch.shape)
  break
# Out:
# Image batch shape:  (64, 224, 224, 3)
# Label batch shape:  (64, 224, 224, 3)

# %%
def createaNewModel(bottlnecksize, dropoutstrenght ):
  # Define the model
  model = Sequential()


  #1st convolution layer
  model.add(Conv2D( int( 16*bottlnecksize), (3, 3), padding='same', input_shape=(SIZE,SIZE,3)))
  model.add(Activation('relu'))
  model.add(Dropout(dropoutstrenght) )
  model.add(MaxPooling2D(pool_size=(2,2), padding='same'))


  #2nd convolution layer
  model.add(Conv2D( int( 32*bottlnecksize),(3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(Dropout(dropoutstrenght) )
  
  model.add(MaxPooling2D(pool_size=(2,2), padding='same'))

  #2nd convolution layer
  model.add(Conv2D( int(64*bottlnecksize),(3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(Dropout(dropoutstrenght) )

  model.add(MaxPooling2D(pool_size=(2,2), padding='same'))


  #3nd convolution layer
  model.add(Conv2D( int( 128*bottlnecksize),(3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(Dropout(dropoutstrenght) )

  #model.add(MaxPooling2D(pool_size=(2,2), padding='same'))



  model.add(Conv2D( int( 32*bottlnecksize),(3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(Dropout(dropoutstrenght) )


  model.add(Conv2D( int( 32*bottlnecksize),(3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(Dropout(dropoutstrenght) )



  model.add(Conv2D( int(128*bottlnecksize),(3, 3), padding='same'))
  model.add(Activation('relu'))
  #model.add(UpSampling2D((2, 2)))
  model.add(Dropout(dropoutstrenght) )



  model.add(Conv2D( int( 64*bottlnecksize),(3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(UpSampling2D((2, 2)))
  model.add(Dropout(dropoutstrenght) )


  #-------------------------
  #4rd convolution layer
  model.add(Conv2D( int( 32*bottlnecksize),(3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(UpSampling2D((2, 2)))
  model.add(Dropout(dropoutstrenght) )


  #5rd convolution layer
  model.add(Conv2D( int( 16*bottlnecksize),(3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(UpSampling2D((2, 2)))

  #-------------------------

  model.add(Conv2D(3,(3, 3), padding='same'))
  model.add(Activation('sigmoid'))

  model.summary()

  # Compile the model
  model.compile(optimizer='adadelta', loss='binary_crossentropy', metrics=['mse'])

  return model

# %%
steps_per_epoch = 1200 / BATCHSIZE

# %%
listofModels = []
listofHistory = []
listofParambottlenect = []
listofParamdrop = []
listofmse = []

# %%
for bottlenecksize in range(1, 5 ):
   for dropout in range(0, 9, 2):
    print("BOTTLENECK is " + str(bottlenecksize))
    print("DROPOUT IS " + str(dropout))
    bottlenecksize2 = bottlenecksize
    bottlenecksizeToUse =  bottlenecksize2 * 1/16
    dropoutToUse = dropout * 1/10
    model = createaNewModel(bottlenecksizeToUse,  dropoutToUse)
    history = model.fit_generator( 
        train_generator,
        steps_per_epoch=1200 // BATCHSIZE,
        epochs=40,
        validation_data=validation_generator,
        validation_steps=128 // BATCHSIZE)
    listofModels.append(model)
    listofHistory.append(history)
    listofParambottlenect.append(bottlenecksizeToUse)
    listofParamdrop.append(dropoutToUse)
# Out:
# BOTTLENECK is 1
# DROPOUT IS 0
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 1)       28
# _________________________________________________________________
# activation_1 (Activation)    (None, 224, 224, 1)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 224, 224, 1)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 112, 112, 1)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 2)       20
# _________________________________________________________________
# activation_2 (Activation)    (None, 112, 112, 2)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 112, 112, 2)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 56, 56, 2)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 4)         76
# _________________________________________________________________
# activation_3 (Activation)    (None, 56, 56, 4)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 56, 56, 4)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 28, 28, 4)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 8)         296
# _________________________________________________________________
# activation_4 (Activation)    (None, 28, 28, 8)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 28, 28, 8)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 2)         146
# _________________________________________________________________
# activation_5 (Activation)    (None, 28, 28, 2)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 28, 28, 2)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 2)         38
# _________________________________________________________________
# activation_6 (Activation)    (None, 28, 28, 2)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 28, 28, 2)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 8)         152
# _________________________________________________________________
# activation_7 (Activation)    (None, 28, 28, 8)         0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 28, 28, 8)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 4)         292
# _________________________________________________________________
# activation_8 (Activation)    (None, 28, 28, 4)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 56, 56, 4)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 56, 56, 4)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 56, 56, 2)         74
# _________________________________________________________________
# activation_9 (Activation)    (None, 56, 56, 2)         0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 112, 112, 2)       0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 112, 112, 2)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 112, 112, 1)       19
# _________________________________________________________________
# activation_10 (Activation)   (None, 112, 112, 1)       0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 224, 224, 1)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 224, 224, 3)       30
# _________________________________________________________________
# activation_11 (Activation)   (None, 224, 224, 3)       0
# =================================================================
# Total params: 1,171
# Trainable params: 1,171
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/40
# 18/18 [==============================] - 18s 994ms/step - loss: 0.6900 - mse: 0.0625 - val_loss: 0.6812 - val_mse: 0.0836
# Epoch 2/40
# 18/18 [==============================] - 15s 811ms/step - loss: 0.6730 - mse: 0.0541 - val_loss: 0.6294 - val_mse: 0.0596
# Epoch 3/40
# 18/18 [==============================] - 15s 829ms/step - loss: 0.6518 - mse: 0.0437 - val_loss: 0.6268 - val_mse: 0.0566
# Epoch 4/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.6488 - mse: 0.0424 - val_loss: 0.6221 - val_mse: 0.0551
# Epoch 5/40
# 18/18 [==============================] - 15s 829ms/step - loss: 0.6482 - mse: 0.0421 - val_loss: 0.6213 - val_mse: 0.0552
# Epoch 6/40
# 18/18 [==============================] - 15s 836ms/step - loss: 0.6481 - mse: 0.0421 - val_loss: 0.6269 - val_mse: 0.0566
# Epoch 7/40
# 18/18 [==============================] - 15s 832ms/step - loss: 0.6481 - mse: 0.0420 - val_loss: 0.6217 - val_mse: 0.0553
# Epoch 8/40
# 18/18 [==============================] - 15s 834ms/step - loss: 0.6475 - mse: 0.0418 - val_loss: 0.6144 - val_mse: 0.0514
# Epoch 9/40
# 18/18 [==============================] - 15s 838ms/step - loss: 0.6474 - mse: 0.0417 - val_loss: 0.6198 - val_mse: 0.0549
# Epoch 10/40
# 18/18 [==============================] - 15s 831ms/step - loss: 0.6466 - mse: 0.0414 - val_loss: 0.6238 - val_mse: 0.0561
# Epoch 11/40
# 18/18 [==============================] - 15s 840ms/step - loss: 0.6465 - mse: 0.0414 - val_loss: 0.6265 - val_mse: 0.0578
# Epoch 12/40
# 18/18 [==============================] - 15s 830ms/step - loss: 0.6459 - mse: 0.0410 - val_loss: 0.6120 - val_mse: 0.0499
# Epoch 13/40
# 18/18 [==============================] - 15s 836ms/step - loss: 0.6459 - mse: 0.0410 - val_loss: 0.5982 - val_mse: 0.0465
# Epoch 14/40
# 18/18 [==============================] - 15s 840ms/step - loss: 0.6423 - mse: 0.0395 - val_loss: 0.6130 - val_mse: 0.0506
# Epoch 15/40
# 18/18 [==============================] - 15s 839ms/step - loss: 0.6425 - mse: 0.0397 - val_loss: 0.6278 - val_mse: 0.0563
# Epoch 16/40
# 18/18 [==============================] - 15s 843ms/step - loss: 0.6379 - mse: 0.0375 - val_loss: 0.5550 - val_mse: 0.0267
# Epoch 17/40
# 18/18 [==============================] - 15s 836ms/step - loss: 0.6144 - mse: 0.0275 - val_loss: 0.5892 - val_mse: 0.0407
# Epoch 18/40
# 18/18 [==============================] - 15s 844ms/step - loss: 0.6153 - mse: 0.0277 - val_loss: 0.5512 - val_mse: 0.0229
# Epoch 19/40
# 18/18 [==============================] - 15s 834ms/step - loss: 0.6115 - mse: 0.0260 - val_loss: 0.5407 - val_mse: 0.0207
# Epoch 20/40
# 18/18 [==============================] - 15s 833ms/step - loss: 0.6093 - mse: 0.0251 - val_loss: 0.5413 - val_mse: 0.0208
# Epoch 21/40
# 18/18 [==============================] - 15s 830ms/step - loss: 0.6071 - mse: 0.0241 - val_loss: 0.5413 - val_mse: 0.0199
# Epoch 22/40
# 18/18 [==============================] - 15s 833ms/step - loss: 0.6058 - mse: 0.0236 - val_loss: 0.5362 - val_mse: 0.0191
# Epoch 23/40
# 18/18 [==============================] - 15s 829ms/step - loss: 0.6058 - mse: 0.0235 - val_loss: 0.5344 - val_mse: 0.0188
# Epoch 24/40
# 18/18 [==============================] - 15s 829ms/step - loss: 0.6051 - mse: 0.0231 - val_loss: 0.5343 - val_mse: 0.0185
# Epoch 25/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6021 - mse: 0.0220 - val_loss: 0.5351 - val_mse: 0.0183
# Epoch 26/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6033 - mse: 0.0223 - val_loss: 0.5311 - val_mse: 0.0174
# Epoch 27/40
# 18/18 [==============================] - 15s 833ms/step - loss: 0.6017 - mse: 0.0217 - val_loss: 0.5362 - val_mse: 0.0182
# Epoch 28/40
# 18/18 [==============================] - 15s 832ms/step - loss: 0.6015 - mse: 0.0215 - val_loss: 0.5301 - val_mse: 0.0174
# Epoch 29/40
# 18/18 [==============================] - 15s 832ms/step - loss: 0.6008 - mse: 0.0212 - val_loss: 0.5259 - val_mse: 0.0166
# Epoch 30/40
# 18/18 [==============================] - 15s 830ms/step - loss: 0.5988 - mse: 0.0205 - val_loss: 0.5308 - val_mse: 0.0164
# Epoch 31/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.5985 - mse: 0.0203 - val_loss: 0.5313 - val_mse: 0.0173
# Epoch 32/40
# 18/18 [==============================] - 15s 834ms/step - loss: 0.5992 - mse: 0.0206 - val_loss: 0.5289 - val_mse: 0.0168
# Epoch 33/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.5990 - mse: 0.0204 - val_loss: 0.5278 - val_mse: 0.0164
# Epoch 34/40
# 18/18 [==============================] - 15s 837ms/step - loss: 0.5978 - mse: 0.0200 - val_loss: 0.5328 - val_mse: 0.0161
# Epoch 35/40
# 18/18 [==============================] - 15s 833ms/step - loss: 0.5970 - mse: 0.0196 - val_loss: 0.5289 - val_mse: 0.0158
# Epoch 36/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.5969 - mse: 0.0196 - val_loss: 0.5389 - val_mse: 0.0165
# Epoch 37/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.5981 - mse: 0.0200 - val_loss: 0.5334 - val_mse: 0.0160
# Epoch 38/40
# 18/18 [==============================] - 15s 831ms/step - loss: 0.5974 - mse: 0.0197 - val_loss: 0.5279 - val_mse: 0.0160
# Epoch 39/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.5976 - mse: 0.0198 - val_loss: 0.5313 - val_mse: 0.0159
# Epoch 40/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.5972 - mse: 0.0196 - val_loss: 0.5253 - val_mse: 0.0154
# BOTTLENECK is 1
# DROPOUT IS 2
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 224, 224, 1)       28
# _________________________________________________________________
# activation_12 (Activation)   (None, 224, 224, 1)       0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 224, 224, 1)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 112, 112, 1)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 112, 112, 2)       20
# _________________________________________________________________
# activation_13 (Activation)   (None, 112, 112, 2)       0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 112, 112, 2)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 56, 56, 2)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 56, 56, 4)         76
# _________________________________________________________________
# activation_14 (Activation)   (None, 56, 56, 4)         0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 56, 56, 4)         0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 28, 28, 4)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 28, 28, 8)         296
# _________________________________________________________________
# activation_15 (Activation)   (None, 28, 28, 8)         0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 28, 28, 8)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 28, 28, 2)         146
# _________________________________________________________________
# activation_16 (Activation)   (None, 28, 28, 2)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 28, 28, 2)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 28, 28, 2)         38
# _________________________________________________________________
# activation_17 (Activation)   (None, 28, 28, 2)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 28, 28, 2)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 28, 28, 8)         152
# _________________________________________________________________
# activation_18 (Activation)   (None, 28, 28, 8)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 28, 28, 8)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 28, 28, 4)         292
# _________________________________________________________________
# activation_19 (Activation)   (None, 28, 28, 4)         0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 56, 56, 4)         0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 56, 56, 4)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 56, 56, 2)         74
# _________________________________________________________________
# activation_20 (Activation)   (None, 56, 56, 2)         0
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 112, 112, 2)       0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 112, 112, 2)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 112, 112, 1)       19
# _________________________________________________________________
# activation_21 (Activation)   (None, 112, 112, 1)       0
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 224, 224, 1)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 224, 224, 3)       30
# _________________________________________________________________
# activation_22 (Activation)   (None, 224, 224, 3)       0
# =================================================================
# Total params: 1,171
# Trainable params: 1,171
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 18/18 [==============================] - 15s 856ms/step - loss: 0.6916 - mse: 0.0633 - val_loss: 0.6894 - val_mse: 0.0877
# Epoch 2/40
# 18/18 [==============================] - 15s 820ms/step - loss: 0.6884 - mse: 0.0616 - val_loss: 0.6859 - val_mse: 0.0859
# Epoch 3/40
# 18/18 [==============================] - 15s 835ms/step - loss: 0.6854 - mse: 0.0601 - val_loss: 0.6822 - val_mse: 0.0841
# Epoch 4/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6825 - mse: 0.0587 - val_loss: 0.6790 - val_mse: 0.0824
# Epoch 5/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6799 - mse: 0.0574 - val_loss: 0.6758 - val_mse: 0.0808
# Epoch 6/40
# 18/18 [==============================] - 15s 829ms/step - loss: 0.6774 - mse: 0.0562 - val_loss: 0.6725 - val_mse: 0.0793
# Epoch 7/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6751 - mse: 0.0550 - val_loss: 0.6694 - val_mse: 0.0778
# Epoch 8/40
# 18/18 [==============================] - 15s 834ms/step - loss: 0.6730 - mse: 0.0539 - val_loss: 0.6671 - val_mse: 0.0764
# Epoch 9/40
# 18/18 [==============================] - 15s 833ms/step - loss: 0.6709 - mse: 0.0530 - val_loss: 0.6638 - val_mse: 0.0751
# Epoch 10/40
# 18/18 [==============================] - 15s 834ms/step - loss: 0.6691 - mse: 0.0520 - val_loss: 0.6614 - val_mse: 0.0738
# Epoch 11/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6673 - mse: 0.0512 - val_loss: 0.6595 - val_mse: 0.0727
# Epoch 12/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6656 - mse: 0.0504 - val_loss: 0.6574 - val_mse: 0.0715
# Epoch 13/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.6641 - mse: 0.0496 - val_loss: 0.6535 - val_mse: 0.0704
# Epoch 14/40
# 18/18 [==============================] - 15s 829ms/step - loss: 0.6627 - mse: 0.0489 - val_loss: 0.6519 - val_mse: 0.0694
# Epoch 15/40
# 18/18 [==============================] - 15s 842ms/step - loss: 0.6614 - mse: 0.0483 - val_loss: 0.6489 - val_mse: 0.0684
# Epoch 16/40
# 18/18 [==============================] - 15s 829ms/step - loss: 0.6602 - mse: 0.0477 - val_loss: 0.6477 - val_mse: 0.0675
# Epoch 17/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6591 - mse: 0.0471 - val_loss: 0.6468 - val_mse: 0.0666
# Epoch 18/40
# 18/18 [==============================] - 15s 833ms/step - loss: 0.6580 - mse: 0.0467 - val_loss: 0.6451 - val_mse: 0.0659
# Epoch 19/40
# 18/18 [==============================] - 15s 843ms/step - loss: 0.6571 - mse: 0.0462 - val_loss: 0.6450 - val_mse: 0.0651
# Epoch 20/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6562 - mse: 0.0458 - val_loss: 0.6410 - val_mse: 0.0643
# Epoch 21/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6554 - mse: 0.0454 - val_loss: 0.6431 - val_mse: 0.0637
# Epoch 22/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6546 - mse: 0.0450 - val_loss: 0.6395 - val_mse: 0.0630
# Epoch 23/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6540 - mse: 0.0447 - val_loss: 0.6367 - val_mse: 0.0624
# Epoch 24/40
# 18/18 [==============================] - 15s 832ms/step - loss: 0.6534 - mse: 0.0444 - val_loss: 0.6350 - val_mse: 0.0619
# Epoch 25/40
# 18/18 [==============================] - 15s 830ms/step - loss: 0.6528 - mse: 0.0442 - val_loss: 0.6367 - val_mse: 0.0613
# Epoch 26/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.6523 - mse: 0.0440 - val_loss: 0.6362 - val_mse: 0.0608
# Epoch 27/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6519 - mse: 0.0438 - val_loss: 0.6332 - val_mse: 0.0604
# Epoch 28/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6515 - mse: 0.0436 - val_loss: 0.6312 - val_mse: 0.0600
# Epoch 29/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6512 - mse: 0.0434 - val_loss: 0.6328 - val_mse: 0.0596
# Epoch 30/40
# 18/18 [==============================] - 15s 836ms/step - loss: 0.6509 - mse: 0.0433 - val_loss: 0.6302 - val_mse: 0.0592
# Epoch 31/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.6506 - mse: 0.0432 - val_loss: 0.6322 - val_mse: 0.0589
# Epoch 32/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6504 - mse: 0.0431 - val_loss: 0.6296 - val_mse: 0.0586
# Epoch 33/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6502 - mse: 0.0430 - val_loss: 0.6297 - val_mse: 0.0583
# Epoch 34/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.6500 - mse: 0.0429 - val_loss: 0.6285 - val_mse: 0.0581
# Epoch 35/40
# 18/18 [==============================] - 15s 834ms/step - loss: 0.6499 - mse: 0.0428 - val_loss: 0.6280 - val_mse: 0.0578
# Epoch 36/40
# 18/18 [==============================] - 15s 842ms/step - loss: 0.6498 - mse: 0.0428 - val_loss: 0.6297 - val_mse: 0.0576
# Epoch 37/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6497 - mse: 0.0427 - val_loss: 0.6244 - val_mse: 0.0574
# Epoch 38/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6496 - mse: 0.0427 - val_loss: 0.6284 - val_mse: 0.0572
# Epoch 39/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6235 - val_mse: 0.0571
# Epoch 40/40
# 18/18 [==============================] - 15s 831ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6243 - val_mse: 0.0569
# BOTTLENECK is 1
# DROPOUT IS 4
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_23 (Conv2D)           (None, 224, 224, 1)       28
# _________________________________________________________________
# activation_23 (Activation)   (None, 224, 224, 1)       0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 224, 224, 1)       0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 112, 112, 1)       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 112, 112, 2)       20
# _________________________________________________________________
# activation_24 (Activation)   (None, 112, 112, 2)       0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 112, 112, 2)       0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 56, 56, 2)         0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 56, 56, 4)         76
# _________________________________________________________________
# activation_25 (Activation)   (None, 56, 56, 4)         0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 56, 56, 4)         0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 28, 28, 4)         0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 28, 28, 8)         296
# _________________________________________________________________
# activation_26 (Activation)   (None, 28, 28, 8)         0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 28, 28, 8)         0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 28, 28, 2)         146
# _________________________________________________________________
# activation_27 (Activation)   (None, 28, 28, 2)         0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 28, 28, 2)         0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 28, 28, 2)         38
# _________________________________________________________________
# activation_28 (Activation)   (None, 28, 28, 2)         0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 28, 28, 2)         0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 28, 28, 8)         152
# _________________________________________________________________
# activation_29 (Activation)   (None, 28, 28, 8)         0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 28, 28, 8)         0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 28, 28, 4)         292
# _________________________________________________________________
# activation_30 (Activation)   (None, 28, 28, 4)         0
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 56, 56, 4)         0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 56, 56, 4)         0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 56, 56, 2)         74
# _________________________________________________________________
# activation_31 (Activation)   (None, 56, 56, 2)         0
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 112, 112, 2)       0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 112, 112, 2)       0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 112, 112, 1)       19
# _________________________________________________________________
# activation_32 (Activation)   (None, 112, 112, 1)       0
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 224, 224, 1)       0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 224, 224, 3)       30
# _________________________________________________________________
# activation_33 (Activation)   (None, 224, 224, 3)       0
# =================================================================
# Total params: 1,171
# Trainable params: 1,171
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 18/18 [==============================] - 15s 858ms/step - loss: 0.6886 - mse: 0.0618 - val_loss: 0.6853 - val_mse: 0.0856
# Epoch 2/40
# 18/18 [==============================] - 15s 817ms/step - loss: 0.6759 - mse: 0.0554 - val_loss: 0.6576 - val_mse: 0.0719
# Epoch 3/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6616 - mse: 0.0483 - val_loss: 0.6314 - val_mse: 0.0594
# Epoch 4/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6534 - mse: 0.0444 - val_loss: 0.6235 - val_mse: 0.0570
# Epoch 5/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6515 - mse: 0.0436 - val_loss: 0.6241 - val_mse: 0.0565
# Epoch 6/40
# 18/18 [==============================] - 15s 834ms/step - loss: 0.6510 - mse: 0.0434 - val_loss: 0.6283 - val_mse: 0.0574
# Epoch 7/40
# 18/18 [==============================] - 15s 824ms/step - loss: 0.6507 - mse: 0.0432 - val_loss: 0.6266 - val_mse: 0.0568
# Epoch 8/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6506 - mse: 0.0432 - val_loss: 0.6279 - val_mse: 0.0572
# Epoch 9/40
# 18/18 [==============================] - 15s 829ms/step - loss: 0.6504 - mse: 0.0431 - val_loss: 0.6235 - val_mse: 0.0565
# Epoch 10/40
# 18/18 [==============================] - 15s 831ms/step - loss: 0.6503 - mse: 0.0430 - val_loss: 0.6252 - val_mse: 0.0571
# Epoch 11/40
# 18/18 [==============================] - 15s 832ms/step - loss: 0.6502 - mse: 0.0430 - val_loss: 0.6266 - val_mse: 0.0567
# Epoch 12/40
# 18/18 [==============================] - 15s 821ms/step - loss: 0.6500 - mse: 0.0429 - val_loss: 0.6288 - val_mse: 0.0576
# Epoch 13/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6487 - mse: 0.0423 - val_loss: 0.6152 - val_mse: 0.0530
# Epoch 14/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6478 - mse: 0.0420 - val_loss: 0.6294 - val_mse: 0.0587
# Epoch 15/40
# 18/18 [==============================] - 15s 824ms/step - loss: 0.6411 - mse: 0.0392 - val_loss: 0.5854 - val_mse: 0.0426
# Epoch 16/40
# 18/18 [==============================] - 15s 838ms/step - loss: 0.6304 - mse: 0.0341 - val_loss: 0.5814 - val_mse: 0.0377
# Epoch 17/40
# 18/18 [==============================] - 15s 832ms/step - loss: 0.6269 - mse: 0.0325 - val_loss: 0.5757 - val_mse: 0.0360
# Epoch 18/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6246 - mse: 0.0314 - val_loss: 0.5679 - val_mse: 0.0332
# Epoch 19/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6236 - mse: 0.0310 - val_loss: 0.5722 - val_mse: 0.0344
# Epoch 20/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.6227 - mse: 0.0304 - val_loss: 0.5710 - val_mse: 0.0338
# Epoch 21/40
# 18/18 [==============================] - 15s 824ms/step - loss: 0.6218 - mse: 0.0300 - val_loss: 0.5633 - val_mse: 0.0314
# Epoch 22/40
# 18/18 [==============================] - 15s 836ms/step - loss: 0.6205 - mse: 0.0295 - val_loss: 0.5656 - val_mse: 0.0310
# Epoch 23/40
# 18/18 [==============================] - 15s 830ms/step - loss: 0.6185 - mse: 0.0287 - val_loss: 0.5595 - val_mse: 0.0301
# Epoch 24/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6188 - mse: 0.0287 - val_loss: 0.5613 - val_mse: 0.0295
# Epoch 25/40
# 18/18 [==============================] - 15s 822ms/step - loss: 0.6176 - mse: 0.0282 - val_loss: 0.5730 - val_mse: 0.0327
# Epoch 26/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6175 - mse: 0.0281 - val_loss: 0.5626 - val_mse: 0.0294
# Epoch 27/40
# 18/18 [==============================] - 15s 830ms/step - loss: 0.6157 - mse: 0.0274 - val_loss: 0.5620 - val_mse: 0.0290
# Epoch 28/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.6161 - mse: 0.0275 - val_loss: 0.6072 - val_mse: 0.0481
# Epoch 29/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6157 - mse: 0.0274 - val_loss: 0.6034 - val_mse: 0.0468
# Epoch 30/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.6159 - mse: 0.0274 - val_loss: 0.5969 - val_mse: 0.0433
# Epoch 31/40
# 18/18 [==============================] - 15s 830ms/step - loss: 0.6156 - mse: 0.0273 - val_loss: 0.5679 - val_mse: 0.0311
# Epoch 32/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.6135 - mse: 0.0264 - val_loss: 0.5630 - val_mse: 0.0282
# Epoch 33/40
# 18/18 [==============================] - 15s 830ms/step - loss: 0.6135 - mse: 0.0263 - val_loss: 0.5614 - val_mse: 0.0293
# Epoch 34/40
# 18/18 [==============================] - 15s 823ms/step - loss: 0.6145 - mse: 0.0268 - val_loss: 0.5639 - val_mse: 0.0290
# Epoch 35/40
# 18/18 [==============================] - 15s 829ms/step - loss: 0.6143 - mse: 0.0267 - val_loss: 0.5710 - val_mse: 0.0322
# Epoch 36/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6123 - mse: 0.0259 - val_loss: 0.5641 - val_mse: 0.0296
# Epoch 37/40
# 18/18 [==============================] - 15s 839ms/step - loss: 0.6134 - mse: 0.0262 - val_loss: 0.5672 - val_mse: 0.0302
# Epoch 38/40
# 18/18 [==============================] - 15s 837ms/step - loss: 0.6128 - mse: 0.0260 - val_loss: 0.5689 - val_mse: 0.0313
# Epoch 39/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6131 - mse: 0.0262 - val_loss: 0.5707 - val_mse: 0.0330
# Epoch 40/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6121 - mse: 0.0257 - val_loss: 0.5698 - val_mse: 0.0317
# BOTTLENECK is 1
# DROPOUT IS 6
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_34 (Conv2D)           (None, 224, 224, 1)       28
# _________________________________________________________________
# activation_34 (Activation)   (None, 224, 224, 1)       0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 224, 224, 1)       0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 112, 112, 1)       0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 112, 112, 2)       20
# _________________________________________________________________
# activation_35 (Activation)   (None, 112, 112, 2)       0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 112, 112, 2)       0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 56, 56, 2)         0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 56, 56, 4)         76
# _________________________________________________________________
# activation_36 (Activation)   (None, 56, 56, 4)         0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 56, 56, 4)         0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 28, 28, 4)         0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 28, 28, 8)         296
# _________________________________________________________________
# activation_37 (Activation)   (None, 28, 28, 8)         0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 28, 28, 8)         0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 28, 28, 2)         146
# _________________________________________________________________
# activation_38 (Activation)   (None, 28, 28, 2)         0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 28, 28, 2)         0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 28, 28, 2)         38
# _________________________________________________________________
# activation_39 (Activation)   (None, 28, 28, 2)         0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 28, 28, 2)         0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 28, 28, 8)         152
# _________________________________________________________________
# activation_40 (Activation)   (None, 28, 28, 8)         0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 28, 28, 8)         0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 28, 28, 4)         292
# _________________________________________________________________
# activation_41 (Activation)   (None, 28, 28, 4)         0
# _________________________________________________________________
# up_sampling2d_10 (UpSampling (None, 56, 56, 4)         0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 56, 56, 4)         0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 56, 56, 2)         74
# _________________________________________________________________
# activation_42 (Activation)   (None, 56, 56, 2)         0
# _________________________________________________________________
# up_sampling2d_11 (UpSampling (None, 112, 112, 2)       0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 112, 112, 2)       0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 112, 112, 1)       19
# _________________________________________________________________
# activation_43 (Activation)   (None, 112, 112, 1)       0
# _________________________________________________________________
# up_sampling2d_12 (UpSampling (None, 224, 224, 1)       0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 224, 224, 3)       30
# _________________________________________________________________
# activation_44 (Activation)   (None, 224, 224, 3)       0
# =================================================================
# Total params: 1,171
# Trainable params: 1,171
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 18/18 [==============================] - 15s 847ms/step - loss: 0.7102 - mse: 0.0707 - val_loss: 0.6897 - val_mse: 0.0878
# Epoch 2/40
# 18/18 [==============================] - 15s 817ms/step - loss: 0.6923 - mse: 0.0635 - val_loss: 0.6864 - val_mse: 0.0861
# Epoch 3/40
# 18/18 [==============================] - 15s 831ms/step - loss: 0.6876 - mse: 0.0612 - val_loss: 0.6830 - val_mse: 0.0845
# Epoch 4/40
# 18/18 [==============================] - 15s 831ms/step - loss: 0.6843 - mse: 0.0596 - val_loss: 0.6795 - val_mse: 0.0829
# Epoch 5/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6815 - mse: 0.0582 - val_loss: 0.6766 - val_mse: 0.0814
# Epoch 6/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6790 - mse: 0.0569 - val_loss: 0.6738 - val_mse: 0.0799
# Epoch 7/40
# 18/18 [==============================] - 15s 824ms/step - loss: 0.6766 - mse: 0.0558 - val_loss: 0.6712 - val_mse: 0.0786
# Epoch 8/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.6745 - mse: 0.0547 - val_loss: 0.6685 - val_mse: 0.0772
# Epoch 9/40
# 18/18 [==============================] - 15s 833ms/step - loss: 0.6725 - mse: 0.0538 - val_loss: 0.6663 - val_mse: 0.0760
# Epoch 10/40
# 18/18 [==============================] - 15s 822ms/step - loss: 0.6706 - mse: 0.0528 - val_loss: 0.6634 - val_mse: 0.0747
# Epoch 11/40
# 18/18 [==============================] - 15s 832ms/step - loss: 0.6689 - mse: 0.0519 - val_loss: 0.6612 - val_mse: 0.0736
# Epoch 12/40
# 18/18 [==============================] - 15s 829ms/step - loss: 0.6672 - mse: 0.0511 - val_loss: 0.6588 - val_mse: 0.0724
# Epoch 13/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6656 - mse: 0.0503 - val_loss: 0.6571 - val_mse: 0.0714
# Epoch 14/40
# 18/18 [==============================] - 15s 830ms/step - loss: 0.6642 - mse: 0.0496 - val_loss: 0.6544 - val_mse: 0.0704
# Epoch 15/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6629 - mse: 0.0490 - val_loss: 0.6521 - val_mse: 0.0694
# Epoch 16/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6616 - mse: 0.0484 - val_loss: 0.6520 - val_mse: 0.0685
# Epoch 17/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6604 - mse: 0.0478 - val_loss: 0.6489 - val_mse: 0.0676
# Epoch 18/40
# 18/18 [==============================] - 15s 845ms/step - loss: 0.6593 - mse: 0.0473 - val_loss: 0.6463 - val_mse: 0.0667
# Epoch 19/40
# 18/18 [==============================] - 15s 827ms/step - loss: 0.6583 - mse: 0.0468 - val_loss: 0.6452 - val_mse: 0.0660
# Epoch 20/40
# 18/18 [==============================] - 15s 831ms/step - loss: 0.6573 - mse: 0.0463 - val_loss: 0.6436 - val_mse: 0.0652
# Epoch 21/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6564 - mse: 0.0459 - val_loss: 0.6413 - val_mse: 0.0645
# Epoch 22/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.6556 - mse: 0.0455 - val_loss: 0.6405 - val_mse: 0.0638
# Epoch 23/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6549 - mse: 0.0452 - val_loss: 0.6393 - val_mse: 0.0632
# Epoch 24/40
# 18/18 [==============================] - 15s 829ms/step - loss: 0.6542 - mse: 0.0448 - val_loss: 0.6395 - val_mse: 0.0626
# Epoch 25/40
# 18/18 [==============================] - 15s 831ms/step - loss: 0.6536 - mse: 0.0445 - val_loss: 0.6363 - val_mse: 0.0620
# Epoch 26/40
# 18/18 [==============================] - 15s 824ms/step - loss: 0.6531 - mse: 0.0443 - val_loss: 0.6353 - val_mse: 0.0615
# Epoch 27/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6525 - mse: 0.0440 - val_loss: 0.6358 - val_mse: 0.0610
# Epoch 28/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6521 - mse: 0.0438 - val_loss: 0.6355 - val_mse: 0.0606
# Epoch 29/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6517 - mse: 0.0437 - val_loss: 0.6344 - val_mse: 0.0601
# Epoch 30/40
# 18/18 [==============================] - 15s 832ms/step - loss: 0.6513 - mse: 0.0435 - val_loss: 0.6315 - val_mse: 0.0597
# Epoch 31/40
# 18/18 [==============================] - 15s 833ms/step - loss: 0.6510 - mse: 0.0433 - val_loss: 0.6333 - val_mse: 0.0594
# Epoch 32/40
# 18/18 [==============================] - 15s 828ms/step - loss: 0.6507 - mse: 0.0432 - val_loss: 0.6297 - val_mse: 0.0590
# Epoch 33/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6505 - mse: 0.0431 - val_loss: 0.6318 - val_mse: 0.0587
# Epoch 34/40
# 18/18 [==============================] - 15s 823ms/step - loss: 0.6502 - mse: 0.0430 - val_loss: 0.6271 - val_mse: 0.0584
# Epoch 35/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6501 - mse: 0.0429 - val_loss: 0.6294 - val_mse: 0.0582
# Epoch 36/40
# 18/18 [==============================] - 15s 831ms/step - loss: 0.6499 - mse: 0.0429 - val_loss: 0.6292 - val_mse: 0.0579
# Epoch 37/40
# 18/18 [==============================] - 15s 826ms/step - loss: 0.6498 - mse: 0.0428 - val_loss: 0.6275 - val_mse: 0.0577
# Epoch 38/40
# 18/18 [==============================] - 15s 829ms/step - loss: 0.6497 - mse: 0.0428 - val_loss: 0.6257 - val_mse: 0.0575
# Epoch 39/40
# 18/18 [==============================] - 15s 833ms/step - loss: 0.6497 - mse: 0.0427 - val_loss: 0.6283 - val_mse: 0.0572
# Epoch 40/40
# 18/18 [==============================] - 15s 825ms/step - loss: 0.6496 - mse: 0.0427 - val_loss: 0.6226 - val_mse: 0.0571
# BOTTLENECK is 1
# DROPOUT IS 8
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_45 (Conv2D)           (None, 224, 224, 1)       28
# _________________________________________________________________
# activation_45 (Activation)   (None, 224, 224, 1)       0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 224, 224, 1)       0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 112, 112, 1)       0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 112, 112, 2)       20
# _________________________________________________________________
# activation_46 (Activation)   (None, 112, 112, 2)       0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 112, 112, 2)       0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 56, 56, 2)         0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 56, 56, 4)         76
# _________________________________________________________________
# activation_47 (Activation)   (None, 56, 56, 4)         0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 56, 56, 4)         0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 28, 28, 4)         0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 28, 28, 8)         296
# _________________________________________________________________
# activation_48 (Activation)   (None, 28, 28, 8)         0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 28, 28, 8)         0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 28, 28, 2)         146
# _________________________________________________________________
# activation_49 (Activation)   (None, 28, 28, 2)         0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 28, 28, 2)         0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 28, 28, 2)         38
# _________________________________________________________________
# activation_50 (Activation)   (None, 28, 28, 2)         0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 28, 28, 2)         0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 28, 28, 8)         152
# _________________________________________________________________
# activation_51 (Activation)   (None, 28, 28, 8)         0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 28, 28, 8)         0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 28, 28, 4)         292
# _________________________________________________________________
# activation_52 (Activation)   (None, 28, 28, 4)         0
# _________________________________________________________________
# ...
# Epoch 1/40
# 18/18 [==============================] - 15s 820ms/step - loss: 0.7319 - mse: 0.0750 - val_loss: 0.6900 - val_mse: 0.0880
# Epoch 2/40
# 18/18 [==============================] - 15s 806ms/step - loss: 0.6890 - mse: 0.0619 - val_loss: 0.6859 - val_mse: 0.0859
# Epoch 3/40
# 18/18 [==============================] - 15s 839ms/step - loss: 0.6848 - mse: 0.0598 - val_loss: 0.6816 - val_mse: 0.0838
# Epoch 4/40
# 18/18 [==============================] - 15s 846ms/step - loss: 0.6813 - mse: 0.0581 - val_loss: 0.6767 - val_mse: 0.0815
# Epoch 5/40
# 18/18 [==============================] - 15s 842ms/step - loss: 0.6777 - mse: 0.0563 - val_loss: 0.6715 - val_mse: 0.0789
# Epoch 6/40
# 18/18 [==============================] - 15s 842ms/step - loss: 0.6734 - mse: 0.0542 - val_loss: 0.6647 - val_mse: 0.0755
# Epoch 7/40
# 18/18 [==============================] - 15s 835ms/step - loss: 0.6680 - mse: 0.0516 - val_loss: 0.6554 - val_mse: 0.0708
# Epoch 8/40
# 18/18 [==============================] - 15s 851ms/step - loss: 0.6620 - mse: 0.0486 - val_loss: 0.6445 - val_mse: 0.0653
# Epoch 9/40
# 18/18 [==============================] - 15s 848ms/step - loss: 0.6567 - mse: 0.0460 - val_loss: 0.6329 - val_mse: 0.0609
# Epoch 10/40
# 18/18 [==============================] - 15s 845ms/step - loss: 0.6532 - mse: 0.0443 - val_loss: 0.6301 - val_mse: 0.0585
# Epoch 11/40
# 18/18 [==============================] - 15s 851ms/step - loss: 0.6511 - mse: 0.0434 - val_loss: 0.6256 - val_mse: 0.0566
# Epoch 12/40
# 18/18 [==============================] - 15s 842ms/step - loss: 0.6491 - mse: 0.0425 - val_loss: 0.6207 - val_mse: 0.0544
# Epoch 13/40
# 18/18 [==============================] - 15s 839ms/step - loss: 0.6448 - mse: 0.0407 - val_loss: 0.6257 - val_mse: 0.0538
# Epoch 14/40
# 18/18 [==============================] - 15s 849ms/step - loss: 0.6378 - mse: 0.0377 - val_loss: 0.6437 - val_mse: 0.0616
# Epoch 15/40
# 18/18 [==============================] - 15s 849ms/step - loss: 0.6325 - mse: 0.0353 - val_loss: 0.6822 - val_mse: 0.0771
# Epoch 16/40
# 18/18 [==============================] - 15s 839ms/step - loss: 0.6260 - mse: 0.0325 - val_loss: 0.7143 - val_mse: 0.0833
# Epoch 17/40
# 18/18 [==============================] - 15s 843ms/step - loss: 0.6221 - mse: 0.0306 - val_loss: 0.6898 - val_mse: 0.0798
# Epoch 18/40
# 18/18 [==============================] - 15s 838ms/step - loss: 0.6209 - mse: 0.0300 - val_loss: 0.6849 - val_mse: 0.0777
# Epoch 19/40
# 18/18 [==============================] - 15s 842ms/step - loss: 0.6188 - mse: 0.0291 - val_loss: 0.6986 - val_mse: 0.0803
# Epoch 20/40
# 18/18 [==============================] - 15s 853ms/step - loss: 0.6169 - mse: 0.0283 - val_loss: 0.6929 - val_mse: 0.0800
# Epoch 21/40
# 18/18 [==============================] - 15s 845ms/step - loss: 0.6158 - mse: 0.0278 - val_loss: 0.7026 - val_mse: 0.0795
# Epoch 22/40
# 18/18 [==============================] - 15s 846ms/step - loss: 0.6142 - mse: 0.0271 - val_loss: 0.7128 - val_mse: 0.0820
# Epoch 23/40
# 18/18 [==============================] - 15s 838ms/step - loss: 0.6134 - mse: 0.0267 - val_loss: 0.7129 - val_mse: 0.0825
# Epoch 24/40
# 18/18 [==============================] - 15s 843ms/step - loss: 0.6130 - mse: 0.0265 - val_loss: 0.7131 - val_mse: 0.0816
# Epoch 25/40
# 18/18 [==============================] - 15s 846ms/step - loss: 0.6119 - mse: 0.0261 - val_loss: 0.7267 - val_mse: 0.0831
# Epoch 26/40
# 18/18 [==============================] - 15s 840ms/step - loss: 0.6109 - mse: 0.0256 - val_loss: 0.6935 - val_mse: 0.0776
# Epoch 27/40
# 18/18 [==============================] - 15s 845ms/step - loss: 0.6105 - mse: 0.0255 - val_loss: 0.7022 - val_mse: 0.0808
# Epoch 28/40
# 18/18 [==============================] - 15s 846ms/step - loss: 0.6098 - mse: 0.0251 - val_loss: 0.6770 - val_mse: 0.0724
# Epoch 29/40
# 18/18 [==============================] - 15s 849ms/step - loss: 0.6100 - mse: 0.0253 - val_loss: 0.7005 - val_mse: 0.0816
# Epoch 30/40
# 18/18 [==============================] - 15s 844ms/step - loss: 0.6088 - mse: 0.0247 - val_loss: 0.6470 - val_mse: 0.0663
# Epoch 31/40
# 18/18 [==============================] - 15s 854ms/step - loss: 0.6081 - mse: 0.0244 - val_loss: 0.6993 - val_mse: 0.0780
# Epoch 32/40
# 18/18 [==============================] - 15s 836ms/step - loss: 0.6070 - mse: 0.0239 - val_loss: 0.6396 - val_mse: 0.0615
# Epoch 33/40
# 18/18 [==============================] - 15s 837ms/step - loss: 0.6059 - mse: 0.0235 - val_loss: 0.6690 - val_mse: 0.0699
# Epoch 34/40
# 18/18 [==============================] - 15s 840ms/step - loss: 0.6061 - mse: 0.0236 - val_loss: 0.6541 - val_mse: 0.0669
# Epoch 35/40
# 18/18 [==============================] - 15s 843ms/step - loss: 0.6047 - mse: 0.0230 - val_loss: 0.6525 - val_mse: 0.0674
# Epoch 36/40
# 18/18 [==============================] - 15s 850ms/step - loss: 0.6039 - mse: 0.0227 - val_loss: 0.6819 - val_mse: 0.0732
# Epoch 37/40
# 18/18 [==============================] - 15s 837ms/step - loss: 0.6028 - mse: 0.0222 - val_loss: 0.6572 - val_mse: 0.0656
# Epoch 38/40
# 18/18 [==============================] - 15s 845ms/step - loss: 0.6031 - mse: 0.0223 - val_loss: 0.6216 - val_mse: 0.0561
# Epoch 39/40
# 18/18 [==============================] - 15s 838ms/step - loss: 0.6014 - mse: 0.0216 - val_loss: 0.6345 - val_mse: 0.0602
# Epoch 40/40
# 18/18 [==============================] - 15s 835ms/step - loss: 0.6018 - mse: 0.0217 - val_loss: 0.6136 - val_mse: 0.0571
# BOTTLENECK is 4
# DROPOUT IS 8
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_210 (Conv2D)          (None, 224, 224, 4)       112
# _________________________________________________________________
# activation_210 (Activation)  (None, 224, 224, 4)       0
# _________________________________________________________________
# dropout_172 (Dropout)        (None, 224, 224, 4)       0
# _________________________________________________________________
# max_pooling2d_58 (MaxPooling (None, 112, 112, 4)       0
# _________________________________________________________________
# conv2d_211 (Conv2D)          (None, 112, 112, 8)       296
# _________________________________________________________________
# activation_211 (Activation)  (None, 112, 112, 8)       0
# _________________________________________________________________
# dropout_173 (Dropout)        (None, 112, 112, 8)       0
# _________________________________________________________________
# max_pooling2d_59 (MaxPooling (None, 56, 56, 8)         0
# _________________________________________________________________
# conv2d_212 (Conv2D)          (None, 56, 56, 16)        1168
# _________________________________________________________________
# activation_212 (Activation)  (None, 56, 56, 16)        0
# _________________________________________________________________
# dropout_174 (Dropout)        (None, 56, 56, 16)        0
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_213 (Conv2D)          (None, 28, 28, 32)        4640
# _________________________________________________________________
# activation_213 (Activation)  (None, 28, 28, 32)        0
# _________________________________________________________________
# dropout_175 (Dropout)        (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_214 (Conv2D)          (None, 28, 28, 8)         2312
# _________________________________________________________________
# activation_214 (Activation)  (None, 28, 28, 8)         0
# _________________________________________________________________
# dropout_176 (Dropout)        (None, 28, 28, 8)         0
# _________________________________________________________________
# conv2d_215 (Conv2D)          (None, 28, 28, 8)         584
# _________________________________________________________________
# activation_215 (Activation)  (None, 28, 28, 8)         0
# _________________________________________________________________
# dropout_177 (Dropout)        (None, 28, 28, 8)         0
# _________________________________________________________________
# conv2d_216 (Conv2D)          (None, 28, 28, 32)        2336
# _________________________________________________________________
# activation_216 (Activation)  (None, 28, 28, 32)        0
# _________________________________________________________________
# dropout_178 (Dropout)        (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_217 (Conv2D)          (None, 28, 28, 16)        4624
# _________________________________________________________________
# activation_217 (Activation)  (None, 28, 28, 16)        0
# _________________________________________________________________
# up_sampling2d_58 (UpSampling (None, 56, 56, 16)        0
# _________________________________________________________________
# dropout_179 (Dropout)        (None, 56, 56, 16)        0
# _________________________________________________________________
# conv2d_218 (Conv2D)          (None, 56, 56, 8)         1160
# _________________________________________________________________
# activation_218 (Activation)  (None, 56, 56, 8)         0
# _________________________________________________________________
# up_sampling2d_59 (UpSampling (None, 112, 112, 8)       0
# _________________________________________________________________
# dropout_180 (Dropout)        (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_219 (Conv2D)          (None, 112, 112, 4)       292
# _________________________________________________________________
# activation_219 (Activation)  (None, 112, 112, 4)       0
# _________________________________________________________________
# up_sampling2d_60 (UpSampling (None, 224, 224, 4)       0
# _________________________________________________________________
# conv2d_220 (Conv2D)          (None, 224, 224, 3)       111
# _________________________________________________________________
# activation_220 (Activation)  (None, 224, 224, 3)       0
# =================================================================
# Total params: 17,635
# Trainable params: 17,635
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 18/18 [==============================] - 14s 805ms/step - loss: 5.5847 - mse: 0.2183 - val_loss: 0.6918 - val_mse: 0.0890
# Epoch 2/40
# 18/18 [==============================] - 15s 806ms/step - loss: 1.0706 - mse: 0.1182 - val_loss: 0.6883 - val_mse: 0.0870
# Epoch 3/40
# 18/18 [==============================] - 15s 842ms/step - loss: 0.7648 - mse: 0.0768 - val_loss: 0.6775 - val_mse: 0.0818
# Epoch 4/40
# 18/18 [==============================] - 15s 837ms/step - loss: 0.7140 - mse: 0.0648 - val_loss: 0.6671 - val_mse: 0.0767
# Epoch 5/40
# 18/18 [==============================] - 15s 841ms/step - loss: 0.6905 - mse: 0.0578 - val_loss: 0.6584 - val_mse: 0.0725
# Epoch 6/40
# 18/18 [==============================] - 15s 851ms/step - loss: 0.6780 - mse: 0.0535 - val_loss: 0.6518 - val_mse: 0.0692
# Epoch 7/40
# 18/18 [==============================] - 15s 838ms/step - loss: 0.6699 - mse: 0.0505 - val_loss: 0.6460 - val_mse: 0.0665
# Epoch 8/40
# 18/18 [==============================] - 15s 848ms/step - loss: 0.6637 - mse: 0.0481 - val_loss: 0.6415 - val_mse: 0.0641
# Epoch 9/40
# 18/18 [==============================] - 15s 853ms/step - loss: 0.6593 - mse: 0.0464 - val_loss: 0.6373 - val_mse: 0.0620
# Epoch 10/40
# 18/18 [==============================] - 15s 844ms/step - loss: 0.6557 - mse: 0.0451 - val_loss: 0.6316 - val_mse: 0.0604
# Epoch 11/40
# 18/18 [==============================] - 15s 850ms/step - loss: 0.6536 - mse: 0.0442 - val_loss: 0.6312 - val_mse: 0.0591
# Epoch 12/40
# 18/18 [==============================] - 15s 845ms/step - loss: 0.6518 - mse: 0.0436 - val_loss: 0.6303 - val_mse: 0.0581
# Epoch 13/40
# 18/18 [==============================] - 15s 847ms/step - loss: 0.6509 - mse: 0.0432 - val_loss: 0.6283 - val_mse: 0.0575
# Epoch 14/40
# 18/18 [==============================] - 15s 846ms/step - loss: 0.6503 - mse: 0.0430 - val_loss: 0.6264 - val_mse: 0.0571
# Epoch 15/40
# 18/18 [==============================] - 15s 838ms/step - loss: 0.6500 - mse: 0.0428 - val_loss: 0.6230 - val_mse: 0.0569
# Epoch 16/40
# 18/18 [==============================] - 15s 843ms/step - loss: 0.6498 - mse: 0.0428 - val_loss: 0.6240 - val_mse: 0.0566
# Epoch 17/40
# 18/18 [==============================] - 15s 851ms/step - loss: 0.6497 - mse: 0.0427 - val_loss: 0.6220 - val_mse: 0.0566
# Epoch 18/40
# 18/18 [==============================] - 15s 838ms/step - loss: 0.6496 - mse: 0.0427 - val_loss: 0.6240 - val_mse: 0.0566
# Epoch 19/40
# 18/18 [==============================] - 15s 838ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6268 - val_mse: 0.0566
# Epoch 20/40
# 18/18 [==============================] - 15s 842ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6231 - val_mse: 0.0566
# Epoch 21/40
# 18/18 [==============================] - 15s 843ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6244 - val_mse: 0.0565
# Epoch 22/40
# 18/18 [==============================] - 15s 854ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6275 - val_mse: 0.0565
# Epoch 23/40
# 18/18 [==============================] - 15s 835ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6242 - val_mse: 0.0564
# Epoch 24/40
# 18/18 [==============================] - 15s 837ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6266 - val_mse: 0.0563
# Epoch 25/40
# 18/18 [==============================] - 15s 842ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6233 - val_mse: 0.0564
# Epoch 26/40
# 18/18 [==============================] - 15s 845ms/step - loss: 0.6495 - mse: 0.0426 - val_loss: 0.6280 - val_mse: 0.0567
# Epoch 27/40
# 18/18 [==============================] - 15s 845ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6251 - val_mse: 0.0564
# Epoch 28/40
# 18/18 [==============================] - 15s 838ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6244 - val_mse: 0.0566
# Epoch 29/40
# 18/18 [==============================] - 15s 859ms/step - loss: 0.6495 - mse: 0.0426 - val_loss: 0.6246 - val_mse: 0.0564
# Epoch 30/40
# 18/18 [==============================] - 15s 839ms/step - loss: 0.6495 - mse: 0.0426 - val_loss: 0.6235 - val_mse: 0.0563
# Epoch 31/40
# 18/18 [==============================] - 15s 844ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6259 - val_mse: 0.0565
# Epoch 32/40
# 18/18 [==============================] - 15s 841ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6251 - val_mse: 0.0563
# Epoch 33/40
# 18/18 [==============================] - 15s 851ms/step - loss: 0.6495 - mse: 0.0426 - val_loss: 0.6260 - val_mse: 0.0568
# Epoch 34/40
# 18/18 [==============================] - 15s 841ms/step - loss: 0.6494 - mse: 0.0427 - val_loss: 0.6251 - val_mse: 0.0567
# Epoch 35/40
# 18/18 [==============================] - 15s 837ms/step - loss: 0.6495 - mse: 0.0426 - val_loss: 0.6264 - val_mse: 0.0565
# Epoch 36/40
# 18/18 [==============================] - 15s 846ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6215 - val_mse: 0.0566
# Epoch 37/40
# 18/18 [==============================] - 15s 839ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6224 - val_mse: 0.0564
# Epoch 38/40
# 18/18 [==============================] - 15s 845ms/step - loss: 0.6494 - mse: 0.0427 - val_loss: 0.6265 - val_mse: 0.0564
# Epoch 39/40
# 18/18 [==============================] - 15s 837ms/step - loss: 0.6495 - mse: 0.0426 - val_loss: 0.6262 - val_mse: 0.0566
# Epoch 40/40
# 18/18 [==============================] - 15s 838ms/step - loss: 0.6495 - mse: 0.0427 - val_loss: 0.6266 - val_mse: 0.0564

# %%
 ddcsfsfsfs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-4cf081dac50d> in <module>()
# ----> 1 ddcsfsfsfs
#
# NameError: name 'ddcsfsfsfs' is not defined

# %%
for bottlenecksize in range(16, 5, -4):
   for dropout in range(0, 6, 4):
    print("BOTTLENECK is " + str(bottlenecksize))
    print("DROPOUT IS " + str(dropout))
    bottlenecksizeToUse =  bottlenecksize * 1/8
    dropoutToUse = dropout * 1/10
    model = createaNewModel(bottlenecksizeToUse,  dropoutToUse)
    history = model.fit_generator( 
        train_generator,
        steps_per_epoch=1200 // BATCHSIZE,
        epochs=1,
        validation_data=validation_generator,
        validation_steps=128 // BATCHSIZE)
    listofModels.append(model)
    listofHistory.append(history)
    listofParambottlenect.append(bottlenecksizeToUse)
    listofParamdrop.append(dropoutToUse)

# %%
 
 listoflegands = []

# %%
listofmse = []
for i in range(0, len(listofModels)):
  history  = listofHistory[i]
  arrayofmse = history.history['mse']
  lastmse = arrayofmse[ len( arrayofmse ) -1]
  listofmse.append(lastmse)

# %%
for i in range(0, len(listofModels)):
  print( str(i) + ' ,  ' + str( listofParambottlenect[i] )+ '  ,  ' + str(listofParamdrop[i])  + ' ,   '  + str(  listofmse[i] ) )
# Out:
# 0 ,  0.0625  ,  0.0 ,   0.01961857
# 1 ,  0.0625  ,  0.2 ,   0.042672195
# 2 ,  0.0625  ,  0.4 ,   0.025702396
# 3 ,  0.0625  ,  0.6 ,   0.04269088
# 4 ,  0.0625  ,  0.8 ,   0.042640224
# 5 ,  0.125  ,  0.0 ,   0.015457242
# 6 ,  0.125  ,  0.2 ,   0.042676955
# 7 ,  0.125  ,  0.4 ,   0.024196379
# 8 ,  0.125  ,  0.6 ,   0.042653125
# 9 ,  0.125  ,  0.8 ,   0.042730786
# 10 ,  0.1875  ,  0.0 ,   0.015215976
# 11 ,  0.1875  ,  0.2 ,   0.03190378
# 12 ,  0.1875  ,  0.4 ,   0.022294497
# 13 ,  0.1875  ,  0.6 ,   0.021382095
# 14 ,  0.1875  ,  0.8 ,   0.04290563
# 15 ,  0.25  ,  0.0 ,   0.013142016
# 16 ,  0.25  ,  0.2 ,   0.015244604
# 17 ,  0.25  ,  0.4 ,   0.019208109
# 18 ,  0.25  ,  0.6 ,   0.02173536
# 19 ,  0.25  ,  0.8 ,   0.042656817

# %%
for i in range(0, len(listofModels)):
  bottlneck = listofParambottlenect[i]
  history = listofHistory[i]
  plt.plot(history.history['mse'])
  legend1 = 'B=' + str (listofParambottlenect[i]) + ', D=' + str(listofParamdrop[i])
  listoflegands.append(legend1)

plt.legend(listoflegands,  bbox_to_anchor=(1.05, 1)) 

plt.show()

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  bottlneck = listofParambottlenect[i]
  print(bottlneck)

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  bottlneck = listofParambottlenect[i]
  print(bottlneck)

# %%
color_sequence = ['#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c',
                  '#98df8a', '#d62728', '#ff9896', '#9467bd', '#c5b0d5',
                  '#8c564b', '#c49c94', '#e377c2', '#f7b6d2', '#7f7f7f',
                  '#c7c7c7', '#bcbd22', '#dbdb8d', '#17becf', '#9edae5']

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  bottlneck = listofParambottlenect[i]
  if bottlneck == 0.25:
    history = listofHistory[i]
    plt.plot(history.history['mse'], color_sequence[i])
    legend1 = 'B=' + str (listofParambottlenect[i]) + ', D=' + str(listofParamdrop[i])
    listoflegands.append(legend1)


plt.legend(listoflegands)
plt.show()

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  bottlneck = listofParambottlenect[i]
  if bottlneck == 0.125:
    history = listofHistory[i]
    plt.plot(history.history['mse'], color_sequence[i])
    legend1 = 'B=' + str (listofParambottlenect[i]) + ', D=' + str(listofParamdrop[i])
    listoflegands.append(legend1)


plt.legend(listoflegands)
plt.show()

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  bottlneck = listofParambottlenect[i]
  if bottlneck == 0.0625:
    history = listofHistory[i]
    plt.plot(history.history['mse'], color_sequence[i])
    legend1 = 'B=' + str (listofParambottlenect[i]) + ', D=' + str(listofParamdrop[i])
    listoflegands.append(legend1)


plt.legend(listoflegands)
plt.show()

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  bottlneck = listofParamdrop [i]
  if  listofmse[i] < 0.03 :
    history = listofHistory[i]
    plt.plot(history.history['mse'], color_sequence[i])
    legend1 =  'D=' + str(listofParamdrop[i]) + '    B=' + str ( int( listofParambottlenect[i] * 16) )
    listoflegands.append(legend1)


plt.legend(listoflegands, loc='upper left', bbox_to_anchor=(1.05, 1))
plt.xlabel('epoch')
plt.ylabel('MSE')

plt.show()

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  bottlneck = listofParamdrop [i]
  if  listofmse[i] < 0.019 :
    history = listofHistory[i]
    plt.plot(history.history['mse'], color_sequence[i])
    legend1 =  'D=' + str(listofParamdrop[i]) + '    B=' + str ( int( listofParambottlenect[i] * 16) )
    listoflegands.append(legend1)


plt.legend(listoflegands, loc='upper left', bbox_to_anchor=(1.05, 1))
plt.xlabel('epoch')
plt.ylabel('MSE')

plt.show()

# %%
listoflegands = []
colourcounti = 0
for i in range(0, len(listofModels)):
  dropout33 = listofParamdrop [i]
  if  dropout33 == 0.0 :
    history = listofHistory[i]
    plt.plot(history.history['mse'])
    colourcounti = colourcounti + 1
    legend1 = 'BottlneckChannels=' + str ( int(listofParambottlenect[i] * 16  * 4)) + ', DropOut=' + str(listofParamdrop[i])
    listoflegands.append(legend1)


plt.legend(listoflegands, loc='upper left', bbox_to_anchor=(1.05, 1))
plt.xlabel('epoch')
plt.ylabel('MSE')
plt.ylim(0, 0.1)


plt.show()

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  dropout33 = listofParamdrop [i]
  if  dropout33 == 0.2 :
    history = listofHistory[i]
    plt.plot(history.history['mse'])
    legend1 = 'BottlneckChannels=' + str ( int(listofParambottlenect[i] * 16  * 4)) + ', DropOut=' + str(listofParamdrop[i])
    listoflegands.append(legend1)


plt.legend(listoflegands, loc='upper left', bbox_to_anchor=(1.05, 1))
plt.xlabel('epoch')
plt.ylabel('MSE')
plt.ylim(0, 0.1)


plt.show()

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  dropout33 = listofParamdrop [i]
  if  dropout33 > 0.0 :
    history = listofHistory[i]
    plt.plot(history.history['mse'])
    legend1 = 'Model' + str(i) + '   BottlneckChannels=' + str ( int(listofParambottlenect[i] * 16  * 4)) + ', DropOut=' + str(listofParamdrop[i])
    listoflegands.append(legend1)
plt.legend(listoflegands, loc='upper left', bbox_to_anchor=(1.05, 1))
plt.xlabel('epoch')
plt.ylabel('MSE')
plt.ylim(0, 0.1)
plt.show()

# %%
#@title Choose model { run: "auto" }

from keras.utils import plot_model
modeltochoose = 16 #@param {type:"slider", min:1, max:20, step:1}

plot_model(listofModels[modeltochoose-1], show_shapes=True, to_file='model.png')

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  dropout33 = listofParamdrop [i]
  if  dropout33 == 0.4 :
    history = listofHistory[i]
    plt.plot(history.history['mse'])
    legend1 = 'BottlneckChannels=' + str ( int(listofParambottlenect[i] * 16  ))  
    listoflegands.append(legend1)


plt.legend(listoflegands, loc='upper left', bbox_to_anchor=(1.05, 1))
plt.xlabel('epoch')
plt.ylabel('MSE')
plt.ylim(0, 0.1)


plt.show()

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  dropout33 = listofParamdrop [i]
  if  dropout33 == 0.6 :
    history = listofHistory[i]
    plt.plot(history.history['mse'] )
    legend1 = 'BottlneckChannels=' + str ( int(listofParambottlenect[i] * 16  * 4)) + ', DropOut=' + str(listofParamdrop[i])
    listoflegands.append(legend1)


plt.legend(listoflegands, loc='upper left', bbox_to_anchor=(1.05, 1))
plt.xlabel('epoch')
plt.ylabel('MSE')
plt.ylim(0, 0.1)


plt.show()

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  dropout33 = listofParamdrop [i]
  if  dropout33 == 0.8 :
    history = listofHistory[i]
    plt.plot(history.history['mse'] )
    legend1 = 'BottlneckChannels=' + str ( int(listofParambottlenect[i] * 16  * 4)) + ', DropOut=' + str(listofParamdrop[i])
    listoflegands.append(legend1)


plt.legend(listoflegands, loc='upper left', bbox_to_anchor=(1.05, 1))
plt.xlabel('epoch')
plt.ylabel('MSE')
plt.ylim(0, 0.1)

plt.show()

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  dropout33 = listofParamdrop [i]
  if  dropout33 == 0.4 :
    history = listofHistory[i]
    plt.plot(history.history['mse'], color_sequence[i])
    legend1 = 'BottlneckChannels=' + str ( int(listofParambottlenect[i] * 16  * 4)) + ', DropOut=' + str(listofParamdrop[i])
    listoflegands.append(legend1)


plt.legend(listoflegands, loc='upper left', bbox_to_anchor=(1.05, 1))
plt.xlabel('epoch')
plt.ylabel('MSE')

plt.show()

# %%
plt.plot(history.history['mse'])
plt.plot(history.history['mse']/2)

# %%
sfsfsfs

# %%
for bottlenecksize in range(16, 1, 4):
  for dropout in range(0, 6, 4):
    bottlenecksizeToUse = int( bottlenecksize * 1/8)
    dropoutToUse = int( dropout * 1/10)
    model = createaNewModel(bottlenecksizeToUse,  dropoutToUse)
    history = model.fit_generator( 
        train_generator,
        steps_per_epoch=1280 // BATCHSIZE,
        epochs=1,
        validation_data=validation_generator,
        validation_steps=128 // BATCHSIZE)
    listofModels.append(model)
    listofHistory.append(history)
    listofParambottlenect.append(bottlenecksizeToUse)
    listofParamdrop.append(dropoutToUse)

# %%
for i in listofModels:
  print (i)

# %%
fsfsfs

# %%
for bottlenecksize in range(1, 16, 2):
  for dropout in range(0, 6, 2):
    bottlenecksizeToUse = bottlenecksize * 1/16
    dropoutToUse = dropout * 1/10
    model = createaNewModel(bottlenecksizeToUse,  dropoutToUse)
    history = model.fit_generator( 
        train_generator,
        steps_per_epoch=1280 // BATCHSIZE,
        epochs=1,
        validation_data=validation_generator,
        validation_steps=128 // BATCHSIZE)
    listofModels.append(model)
    listofHistory.append(history)
    listofParambottlenect.append(bottlenecksizeToUse)
    listofParamdrop.append(dropoutToUse)

# %%
# Train the model
history = model.fit_generator( 
        train_generator,
        steps_per_epoch=1280 // BATCHSIZE,
        epochs=40,
        validation_data=validation_generator,
        validation_steps=128 // BATCHSIZE)

# %%
train_generator.batch_index

# %%
# Test the model
data_list = []
batch_index = 0
while batch_index <= train_generator.batch_index:
    data = train_generator.next()
    print(data[0].shape)
    data_list.append(data[0])
    batch_index = batch_index + 1
    break

# %%
data = train_generator.next()
print(data[0].shape)

# %%
predictedimage = model.predict(data[0])

# %%
predictedimage.shape

# %%
plt.imshow(data[0][30])

# %%
plt.imshow(predictedimage[30])

# %%
layer_outputs = 0

# %%
layer_outputs = [layer.output for layer in model.layers]
# Creates a model that will return these outputs, given the model input:
#activation_model = models.Model(inputs=pre_trained_model.input, outputs=layer_outputs)

print( layer_outputs)

print( layer_outputs[0])
print( layer_outputs[9])

# %%
layerindex = 1
for alayer in model.layers:
  if ("conv" in alayer.name):
    print( str(layerindex) + '  \t' + str(alayer.name) + '\t' +str(alayer.input_shape ) )
  layerindex = layerindex + 1

# %%
pic_index = 8 #@param {type:"slider", min:0, max:100, step:1}

# %%
NanoMaterial = 'spike' #@param ["spike", "blue"]

# %%
seeActivationAtLayer = 2 #@param {type:"slider", min:0, max:29, step:1}

# %%
from keras import models

activation_model = 0
activation_model = models.Model(model.input, outputs=layer_outputs[seeActivationAtLayer])

# %%
print( layer_outputs[6])

# %%
#@title After running this cell manually, it will auto-run if you change the selected value. { run: "auto" }
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

pic_index = 16 #@param {type:"slider", min:0, max:100, step:1}





next_paper = [os.path.join(paper_dir, fname) 
                for fname in paper_files[pic_index-2:pic_index]]


img_path = 0
#for i, img_path in enumerate(next_rock+next_paper+next_scissors):
for i, img_pathany in enumerate(next_paper):
  if True:
    img = mpimg.imread(img_pathany)
    print(img_pathany)
    print(img.shape)
    plt.imshow(img)
    plt.axis('Off')
    plt.show()
    img_path = img_pathany
    break
    
    

img = image.load_img(img_path, target_size=(224, 224))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
# Remember that the model was trained on inputs
# that were preprocessed in the following way:
img_tensor /= 255.

# Its shape is (1, 150, 150, 3)
print(img_tensor.shape)
plt.imshow(img)
plt.show()

predictedimage = model.predict(img_tensor)
plt.imshow(predictedimage[0])

# %%
#@title After running this cell manually, it will auto-run if you change the selected value. { run: "auto" }

seeActivationAtLayer = "3" #@param [1, 2, 3, 4, 5, 7, 9, 11, 13, 15, 16,17, 19, 22, 25]

seeActivationAtLayer = int (seeActivationAtLayer)

from keras import models

activation_model = 0
activation_model = models.Model(model.input, outputs=layer_outputs[seeActivationAtLayer])



activations = activation_model.predict(img_tensor)
first_layer_activation = activations[0]

layer_activation = activations[0]

images_per_row = 16

n_features = layer_activation.shape[-1]

n_features

if n_features <= 4: 
  images_per_row = 2
  
  
size = layer_activation.shape[1]

n_cols = n_features // images_per_row
display_grid = np.zeros((size * n_cols, images_per_row * size))

n_features = layer_activation.shape[-1]
size = layer_activation.shape[1]


print(n_features)

n_cols = n_features // images_per_row



display_grid =0
display_grid = np.zeros((size * n_cols, images_per_row * size))

print(n_cols)
print(display_grid.shape)

# We'll tile each filter into this big horizontal grid
if True:
  for col in range(n_cols):
    for row in range(images_per_row):
              channel_image = layer_activation[
                                               :, :,
                                               col * images_per_row + row]
              # Post-process the feature to make it visually palatable
              channel_image -= channel_image.mean()
              channel_image /= channel_image.std()
              channel_image *= 64
              channel_image += 128
              channel_image = np.clip(channel_image, 0, 255).astype('uint8')
             # print(channel_image.shape)
             # print(col * size)
             # print((col + 1) * size)
              display_grid[col * size : (col + 1) * size,
                           row * size : (row + 1) * size] = channel_image

    # Display the grid
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1] * 2 ,
                          scale * 2 * display_grid.shape[0]))
  plt.imshow(display_grid, aspect='auto', cmap='viridis')
    
plt.show()

# %%
#@title After running this cell manually, it will auto-run if you change the selected value. { run: "auto" }
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

pic_index = 206 #@param {type:"slider", min:0, max:500, step:1}





next_paper = [os.path.join(rock_dir, fname) 
                for fname in rock_files[pic_index-2:pic_index]]


img_path = 0
#for i, img_path in enumerate(next_rock+next_paper+next_scissors):
for i, img_pathany in enumerate(next_paper):
  if True:
    img = mpimg.imread(img_pathany)
    print(img_pathany)
    print(img.shape)
    plt.imshow(img)
    plt.axis('Off')
    plt.show()
    img_path = img_pathany
    break
    
    

img = image.load_img(img_path, target_size=(224, 224))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
# Remember that the model was trained on inputs
# that were preprocessed in the following way:
img_tensor /= 255.

# Its shape is (1, 150, 150, 3)
print(img_tensor.shape)
plt.imshow(img)
plt.show()

predictedimage = model.predict(img_tensor)
plt.imshow(predictedimage[0])

# %%
#@title After running this cell manually, it will auto-run if you change the selected value. { run: "auto" }

seeActivationAtLayer = "7" #@param [1, 2, 3, 4, 5, 6, 7, 9, 11, 13, 14, 15, 16,17, 19, 22, 25, 26, 27, 28]

seeActivationAtLayer = int (seeActivationAtLayer)

from keras import models

activation_model = 0
activation_model = models.Model(model.input, outputs=layer_outputs[seeActivationAtLayer])



activations = activation_model.predict(img_tensor)
first_layer_activation = activations[0]

layer_activation = activations[0]

images_per_row = 16

n_features = layer_activation.shape[-1]

n_features

if n_features <= 4: 
  images_per_row = 2
  
  
size = layer_activation.shape[1]

n_cols = n_features // images_per_row
display_grid = np.zeros((size * n_cols, images_per_row * size))

n_features = layer_activation.shape[-1]
size = layer_activation.shape[1]


print(n_features)

n_cols = n_features // images_per_row



display_grid =0
display_grid = np.zeros((size * n_cols, images_per_row * size))

print(n_cols)
print(display_grid.shape)

# We'll tile each filter into this big horizontal grid
if True:
  for col in range(n_cols):
    for row in range(images_per_row):
              channel_image = layer_activation[
                                               :, :,
                                               col * images_per_row + row]
              # Post-process the feature to make it visually palatable
              channel_image -= channel_image.mean()
              channel_image /= channel_image.std()
              channel_image *= 64
              channel_image += 128
              channel_image = np.clip(channel_image, 0, 255).astype('uint8')
             # print(channel_image.shape)
             # print(col * size)
             # print((col + 1) * size)
              display_grid[col * size : (col + 1) * size,
                           row * size : (row + 1) * size] = channel_image

    # Display the grid
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1] * 2 ,
                          scale * 2 * display_grid.shape[0]))
  plt.imshow(display_grid, aspect='auto', cmap='viridis')
    
plt.show()


from keras.utils import plot_model
plot_model(activation_model, show_shapes=True, show_layer_names=False, to_file='model.png')

# %%
# We preprocess the image into a 4D tensor
from keras.preprocessing import image
import numpy as np

img = image.load_img(img_path, target_size=(224, 224))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
# Remember that the model was trained on inputs
# that were preprocessed in the following way:
img_tensor /= 255.

# Its shape is (1, 150, 150, 3)
print(img_tensor.shape)
plt.imshow(img)

# %%
activations = activation_model.predict(img_tensor)

# %%
activations.shape

# %%
first_layer_activation = activations[0]
print(first_layer_activation.shape)

# %%
import matplotlib.pyplot as plt

# %%
layer_activation = activations[0]

# %%
images_per_row = 16

n_features = layer_activation.shape[-1]

n_features

if n_features <= 4: 
  images_per_row = 2

# %%
size = layer_activation.shape[1]
size

# %%
n_cols = n_features // images_per_row
display_grid = np.zeros((size * n_cols, images_per_row * size))

# %%
n_features = layer_activation.shape[-1]
size = layer_activation.shape[1]


print(n_features)

n_cols = n_features // images_per_row



display_grid =0
display_grid = np.zeros((size * n_cols, images_per_row * size))

print(n_cols)
print(display_grid.shape)

# We'll tile each filter into this big horizontal grid
if True:
  for col in range(n_cols):
    for row in range(images_per_row):
              channel_image = layer_activation[
                                               :, :,
                                               col * images_per_row + row]
              # Post-process the feature to make it visually palatable
              channel_image -= channel_image.mean()
              channel_image /= channel_image.std()
              channel_image *= 64
              channel_image += 128
              channel_image = np.clip(channel_image, 0, 255).astype('uint8')
             # print(channel_image.shape)
             # print(col * size)
             # print((col + 1) * size)
              display_grid[col * size : (col + 1) * size,
                           row * size : (row + 1) * size] = channel_image

    # Display the grid
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1] * 2 ,
                          scale * 2 * display_grid.shape[0]))
  plt.imshow(display_grid, aspect='auto', cmap='viridis')
    
plt.show()

# %%
model.summary()

# %%
from keras.applications import VGG16
from keras import backend as K


layer_name = 'conv2d_3'
filter_index = 0

layer_output = model.get_layer(layer_name).output
loss = K.mean(layer_output[:, :, :, filter_index])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-923cacc621ad> in <module>()
#       6 filter_index = 0
#       7
# ----> 8 layer_output = model.get_layer(layer_name).output
#       9 loss = K.mean(layer_output[:, :, :, filter_index])
#
# /tensorflow-1.15.2/python3.6/keras/engine/network.py in get_layer(self, name, index)
#     363                 return layer
#     364
# --> 365         raise ValueError('No such layer: ' + name)
#     366
#     367     @property
#
# ValueError: No such layer: conv2d_3

# %%
# !ls mynewfilesTEM/blue

# %%
TRAINING_DIR = "mynewfilesTEM/"

datagen = ImageDataGenerator(validation_split=0.1, rescale=1./255,      rotation_range=4,
     horizontal_flip=True,                                                                
     fill_mode='wrap')

train_generator = datagen.flow_from_directory(
    TRAINING_DIR, 
    subset='training',
    target_size=(SIZE,SIZE),
         shuffle=True,     batch_size=BATCHSIZE,
	  class_mode='input'
)

validation_generator = datagen.flow_from_directory(
    TRAINING_DIR,
    subset='validation',
    	target_size=(SIZE,SIZE),
         shuffle=True,     batch_size=BATCHSIZE,
	class_mode='input'
)




test_datagen = ImageDataGenerator( rescale=1./255)


test_generator = test_datagen.flow_from_directory(
    TRAINING_DIR,
    target_size=(SIZE,SIZE),
    batch_size=BATCHSIZE,
    class_mode='input',
    shuffle=True,
    seed=42
)
# Out:
# Found 1 images belonging to 1 classes.
# Found 0 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ab3ea694-ca1f-48d1-a786-00c5f4b53faf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab3ea694-ca1f-48d1-a786-00c5f4b53faf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 30se.png to 30se.png

# %%
# !wget https://raw.githubusercontent.com/rajagopalmotivate1/COVID_NanoAID/master/10.jpg

# %%
# !wget https://raw.githubusercontent.com/rajagopalmotivate1/COVID_NanoAID/master/25.JPG

# %%
# !wget https://raw.githubusercontent.com/rajagopalmotivate1/COVID_NanoAID/master/30.PNG

# %%
# !mv Capture4.JPG mynewfilesTEM/blue/1.jpg

# %%
# !mv CaptureJ.JPG mynewfilesTEM/blue/2.jpg

# %%
# !mv CaptureJesus10.JPG  mynewfilesTEM/blue/3.jpg

# %%
# !mv check1a.JPG  mynewfilesTEM/blue/5.jpg

# %%
# !mv 25.JPG mynewfilesTEM/blue/2.jpg

# %%
# !mv 30se.png mynewfilesTEM/blue/3.jpg

# %%
paper_dir = os.path.join('mynewfilesTEM/blue')
paper_files = os.listdir(paper_dir)

# %%
#@title After running this cell manually, it will auto-run if you change the selected value. { run: "auto" }
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

pic_index = 1 #@param {type:"slider", min:1, max:6, step:1}





next_paper = [os.path.join(paper_dir, fname) 
                for fname in paper_files[pic_index-1:pic_index]]


img_path = 0
#for i, img_path in enumerate(next_rock+next_paper+next_scissors):
for i, img_pathany in enumerate(next_paper):
  if True:
    img = mpimg.imread(img_pathany)
    print(img_pathany)
    print(img.shape)
    plt.imshow(img)
    plt.axis('Off')
    plt.show()
    img_path = img_pathany
    break
    
    

img = image.load_img(img_path, target_size=(224, 224))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
# Remember that the model was trained on inputs
# that were preprocessed in the following way:
img_tensor /= 255.

# Its shape is (1, 150, 150, 3)
print(img_tensor.shape)
plt.imshow(img)
plt.show()

predictedimage = model.predict(img_tensor)
plt.imshow(predictedimage[0])
# Out:
# mynewfilesTEM/blue/3.jpg
# (224, 224, 3)
# (1, 224, 224, 3)

# %%
listoflegands = []
for i in range(0, len(listofModels)):
  dropout33 = listofParamdrop [i]
  if  dropout33 > 0.0 :
    history = listofHistory[i]
    plt.plot(history.history['mse'])
    legend1 = 'Model' + str(i) + '   BottlneckChannels=' + str ( int(listofParambottlenect[i] * 16  * 4)) + ', DropOut=' + str(listofParamdrop[i])
    listoflegands.append(legend1)
plt.legend(listoflegands, loc='upper left', bbox_to_anchor=(1.05, 1))
plt.xlabel('epoch')
plt.ylabel('MSE')
plt.ylim(0, 0.1)
plt.show()

# %%
#@title After running this cell manually, it will auto-run if you change the selected value. { run: "auto" }

model_index = 1 #@param {type:"slider", min:1, max:20, step:1}

model = listofModels[model_index -1]

seeActivationAtLayer = "5" #@param [1, 2, 3, 4, 5, 6, 7, 9, 11, 13, 14, 15, 16,17, 19, 22, 25, 26, 27, 28]

seeActivationAtLayer = int (seeActivationAtLayer)

from keras import models
layer_outputs = [layer.output for layer in model.layers]

activation_model = 0
activation_model = models.Model(model.input, outputs=layer_outputs[seeActivationAtLayer])



activations = activation_model.predict(img_tensor)
first_layer_activation = activations[0]

layer_activation = activations[0]

images_per_row = 16

n_features = layer_activation.shape[-1]

n_features

if n_features <= 4: 
  images_per_row = 2

if n_features <= 2: 
  images_per_row = 1
    
  
size = layer_activation.shape[1]

n_cols = n_features // images_per_row
display_grid = np.zeros((size * n_cols, images_per_row * size))

n_features = layer_activation.shape[-1]
size = layer_activation.shape[1]


print(n_features)

n_cols = n_features // images_per_row



display_grid =0
display_grid = np.zeros((size * n_cols, images_per_row * size))

print(n_cols)
print(display_grid.shape)

# We'll tile each filter into this big horizontal grid
if True:
  for col in range(n_cols):
    for row in range(images_per_row):
              channel_image = layer_activation[
                                               :, :,
                                               col * images_per_row + row]
              # Post-process the feature to make it visually palatable
              channel_image -= channel_image.mean()
              channel_image /= channel_image.std()
              channel_image *= 64
              channel_image += 128
              channel_image = np.clip(channel_image, 0, 255).astype('uint8')
             # print(channel_image.shape)
             # print(col * size)
             # print((col + 1) * size)
              display_grid[col * size : (col + 1) * size,
                           row * size : (row + 1) * size] = channel_image

    # Display the grid
    scale = 1. / size * 2
    plt.figure(figsize=(scale * display_grid.shape[1] * 2 ,                          scale * 2 * display_grid.shape[0]))
  plt.imshow(display_grid, aspect='auto', cmap='viridis')
    
plt.show()
# Out:
# 2
# 2
# (224, 112)

# %%
#@title Save channel that filter SARS-COV-2 spikes 

Feature1_layernumber = 1 #@param {type:"number"}
Feature1_channelnumber = 1 #@param {type:"number"}

# %%
#@title Save channel that filter SARS-COV-2 shape 

Feature1a_layernumber = 3 #@param {type:"number"}
Feature1a_channelnumber = 0 #@param {type:"number"}

# %%
#@title Save channel that filter SARS-COV-2 shape 

Feature2_layernumber = 3 #@param {type:"number"}
Feature2_channelnumber = 63 #@param {type:"number"}

# %%
#@title Save channel that filter SARS-COV-2 shape 

Feature3_layernumber = 1 #@param {type:"number"}
Feature3_channelnumber = 14 #@param {type:"number"}

# %%
import copy
def plotrequiredchannel(seeActivationAtLayer, channel):
  print('       layer: ' + str(seeActivationAtLayer) + ',  channel: ' + str(channel))
  activation_model = models.Model(model.input, outputs=layer_outputs[seeActivationAtLayer])
  activations = activation_model.predict(img_tensor)
  first_layer_activation = activations[0]
  channelimage = first_layer_activation[:, :, 0+channel:1+channel]
  #print(channelimage.shape[0])   #(56,56)
  sizeofthechannelimage = channelimage.shape[0]  
  newimage22 = np.reshape(channelimage, (sizeofthechannelimage,sizeofthechannelimage))
  newimage23 = copy.deepcopy(newimage22)
  newimage22.shape
  newimage22 -= newimage22.mean()
  newimage22 /= newimage22.std()
  newimage22 *= 64
  newimage22 += 128
  newimage22 = np.clip(newimage22, 0, 255).astype('uint8')
  plt.imshow(newimage22)
  print(newimage22.shape)
  return newimage23

# %%
temp = plotrequiredchannel(Feature1_layernumber, Feature1_channelnumber)

# %%
temp = plotrequiredchannel(Feature1a_layernumber, Feature1a_channelnumber)

# %%
temp = plotrequiredchannel(Feature2_layernumber, Feature2_channelnumber)

# %%
temp = plotrequiredchannel(Feature3_layernumber, Feature3_channelnumber)

# %%
plt.imshow(plotrequiredchannel(1, 19)-plotrequiredchannel(1, 2))

# %%
plt.imshow(plotrequiredchannel(1, 14)-plotrequiredchannel(1, 31))

# %%
plotrequiredchannel(1, 1)

# %%
plotrequiredchannel(3, 63)

# %%
plotrequiredchannel(6, 125)

# %%
plotrequiredchannel(1, 2)

# %%
plotrequiredchannel(2, 31)

# %%
for i in range(0,31):
  imag1 = plotrequiredchannel(1, i)
  imag2 = plotrequiredchannel(1, 11)
  plt.imshow(imag1-imag2)
  plt.show()

# %%
for i in range(0,31):
  imag1 = plotrequiredchannel(1, i)
  imag2 = plotrequiredchannel(1, 31)
  print(i)
  plt.imshow(imag1-imag2)
  plt.show()

# %%
for i in range(0,31):
  imag1 = plotrequiredchannel(1, i)
  imag2 = plotrequiredchannel(1, 2)
  plt.imshow(imag1-imag2)
  plt.show()

# %%
for i in range(0,31):
  imag1 = plotrequiredchannel(3, i)
  imag2 = plotrequiredchannel(3, 0)
  print(i)
  plt.imshow(imag1-imag2)
  plt.show()

# %%
plotrequiredchannel(1, 2)

# %%
plotrequiredchannel(1, 14)

# %%
for i in range(0,31):
  imag1 = plotrequiredchannel(1, i)
  imag2 = plotrequiredchannel(1, 14)
  plt.imshow(imag1-imag2)
  plt.show()

# %%
plotrequiredchannel(1, 31)

# %%
plotrequiredchannel(1, 31)

# %%
grads = K.gradients(loss, model.input)[0]

# %%
grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

# %%
iterate = K.function([model.input], [loss, grads])

# Let's test it:
import numpy as np
loss_value, grads_value = iterate([np.zeros((1, 150, 150, 3))])

# %%
# We start from a gray image with some noise
input_img_data = np.random.random((1, 150, 150, 3)) * 20 + 128.

# Run gradient ascent for 40 steps
step = 1.  # this is the magnitude of each gradient update
for i in range(40):
    # Compute the loss value and gradient value
    loss_value, grads_value = iterate([input_img_data])
    # Here we adjust the input image in the direction that maximizes the loss
    input_img_data += grads_value * step

# %%
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
def generate_pattern(layer_name, filter_index, size=150):
    # Build a loss function that maximizes the activation
    # of the nth filter of the layer considered.
    layer_output = model.get_layer(layer_name).output
    loss = K.mean(layer_output[:, :, :, filter_index])

    # Compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, model.input)[0]

    # Normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # This function returns the loss and grads given the input picture
    iterate = K.function([model.input], [loss, grads])
    
    # We start from a gray image with some noise
    input_img_data = np.random.random((1, size, size, 3)) * 20 + 128.

    # Run gradient ascent for 40 steps
    step = 1.
    for i in range(40):
        loss_value, grads_value = iterate([input_img_data])
        input_img_data += grads_value * step
        
    img = input_img_data[0]
    return deprocess_image(img)

# %%
plt.imshow(generate_pattern('conv2d_4', 3))
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec



for j in range(2):
  
  plt.figure(figsize = (16,16))
  gs1 = gridspec.GridSpec(4, 4)
  gs1.update(wspace=0.005, hspace=0.005) # set the spacing between axes. 

  for i in range(16):
     # i = i + 1 # grid spec indexes from 0

      img = generate_pattern('conv2d_3', i + 16*j)

      ax1 = plt.subplot(gs1[i])
      plt.axis('off')
      ax1.set_aspect('equal')
      plt.imshow(img)

  plt.show()

# %%
import os
logdir = os.path.join("logs", "myexp1")
tensorboard_callback = keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# %%
import tensorflow as tf

# %%
load_ext tensorboard

# %%
# %reload_ext tensorboard

# %%
#!kill 426

# %%
activation_model.summary()

# %%
from keras.utils import plot_model
plot_model(activation_model, to_file='model.png')

# %%
# %tensorboard — logdir logs

# %%
data_list[0].shape

# %%
data_list[0][19].shape
